# %%
from google.colab import drive
drive.mount('/content/drive')

root = '/content/drive/MyDrive/Colab Notebooks/FINAL PROJECT ZENIUS/'
# Out:
# Mounted at /content/drive

# %%
import zipfile

zip_ref = zipfile.ZipFile(root + "home-credit-default-risk.zip", 'r')
zip_ref.extractall(root + "Dataset")
zip_ref.close()
